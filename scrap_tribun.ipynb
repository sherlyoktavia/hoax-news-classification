# %%
# %pip install requests
# %pip install beautifulsoup4
# %pip install pandas lxml

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from datetime import datetime
import time

# %%
BASE_URL = "https://www.tribunnews.com/tag/politik"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# %%
def get_article_content(url):
    try:
        r = requests.get(url, headers=HEADERS, timeout=10)
        if r.status_code != 200:
            return None

        soup = BeautifulSoup(r.text, "lxml")

        # PRIORITAS selector isi artikel
        selectors = [
            "div.read__content",
            "div#article-content",
            "div.side-article",
            "article"
        ]

        article_div = None
        for sel in selectors:
            article_div = soup.select_one(sel)
            if article_div:
                break

        if article_div is None:
            return None

        paragraphs = article_div.find_all("p")
        content = []

        for p in paragraphs:
            text = p.get_text(" ", strip=True)

            if len(text) < 30:
                continue
            if "Baca juga" in text:
                continue
            if text.lower().startswith(("reporter", "editor", "penulis")):
                continue

            content.append(text)

        if len(content) == 0:
            return None

        return " ".join(content)

    except Exception as e:
        print("Error article:", e)
        return None

# %%
print("Scraping Tribunnews Politik...")
MAX_PAGE = 10  # 10 halaman ≈ 150 artikel
data = []

for page in range(1, MAX_PAGE + 1):
    url = f"https://www.tribunnews.com/tag/politik?page={page}"
    print("Scraping page:", page)

    r = requests.get(url, headers=HEADERS)
    soup = BeautifulSoup(r.text, "lxml")

    articles = soup.select("li.ptb15")

    for art in articles:
        try:
            title_tag = art.select_one("h3 a")
            if not title_tag:
                continue

            title = title_tag.get_text(strip=True)
            link = title_tag["href"]

            print(f"Scraping:", title)

            content = get_article_content(link)
            if not content:
                continue

            data.append({
                "title": title,
                "url": link,
                "content": content
            })

            time.sleep(2)
        except Exception as e:
            print("Skip article:", e)

print("Total articles scraped:", len(data))
df = pd.DataFrame(data)
df.to_csv(
    "tribunnews_politik_full.csv",
    index=False,
    encoding="utf-8-sig"
)

print("Berhasil disimpan ke tribunnews_politik_full.csv")
print(df.head())
# Out:
# Scraping Tribunnews Politik...
# Scraping page: 1
# Scraping: Tebar Pesona di Tengah Banjir, Masih Efektifkah Politik Pencitraan?
# Scraping: PSI Puji Prabowo Akui Keberhasilan Jokowi: Padahal Musuh Politik 2 Kali Pilpres
# Scraping: Nahdlatul Ulama Diharapkan Tetap Menjadi Rumah Besar Umat, Bukan Panggung Politik
# Scraping: Said Abdullah Sebut Regenerasi Pemilih Muda Jadi Tantangan Masa Depan Politik
# Scraping: Ketua PSI Jabar: Bakal Ada Badai Politik Usai Hadirnya Jokowi
# Scraping: Al Araf Ingatkan Penyimpangan Peran TNI: Jangan Sampai Kalah Perang karena Tentara Sibuk Urus Pangan
# Scraping: Pernyataan Prabowo Tak Takut Dikendalikan Jokowi Dinilai Jadi Strategi untuk Menenangkan Publik
# Scraping: Realisme Politik dan Penegakan Hukum Pemilu
# Scraping: Partai Perindo Akan Menggelar Rakernas di Ancol Jakarta, Dorong Politik Inklusif
# Scraping: Parpol Diminta Ciptakan Ekosistem Politik, Bukan Sekadar Mobilisasi Masyarakat Setiap 5 Tahun
# Scraping: Hari Sumpah Pemuda, Megawati Soekarnoputri Minta Anak Muda Peduli Politik dan Lingkungan
# Scraping: Peringati HUT ke-14, NasDem Tegaskan Politik Kemanusiaan sebagai Fondasi Pembangunan Bangsa
# Scraping: Hari Santri, Prabowo Restui Pembentukan Ditjen Pesantren Hingga Singgung Resolusi Jihad
# Scraping: Jelang Sumpah Pemuda, PDIP Ingatkan Kejayaan Indonesia Lahir dari Lautan, Bukan dari Tembok Baja
# Scraping: Prabowo Tawarkan Beasiswa untuk Pelajar Afrika Selatan, Termasuk di Sekolah Menengah
# Scraping: Sekjen Golkar Respons Soal Soeharto Diusulkan Jadi Pahlawan Nasional: Pak Harto Punya Jasa Besar
# Scraping: Reformasi Polri Bukan Sekadar Agenda Politik, tapi Tuntutan Bangsa yang Ingin Stabilitas
# Scraping: Mantan Agen BIN: Kedatangan Jokowi di Rumah Prabowo Semacam Debt Collector, Menagih Utang Politik
# Scraping: Politik Malaysia Bergejolak Akibat Kontroversi Alkohol
# Scraping: Anies Baswedan: Kita Butuh Orang Cerdas dan Berintegritas di Dunia Politik
# Scraping page: 2
# Scraping: Dari Nepal ke Maroko: Dua Wajah Politik Generasi Z
# Scraping: Jokowi, di Antara Kebencian serta Kerinduan dan Lalu, Dunia Memanggilnya
# Scraping: Bandingkan Pendapatan Anggota Dewan Berdasarkan Prinsip Setara
# Scraping: Aurelie Moeremans Bongkar Cara Partai Politik Rekrut Artis, Singgung Ijazah Instan Langsung S2
# Scraping: Aurelie Moeremans Pernah Ditawari Masuk Partai Politik, Diiming-imingi Gaji Ratusan Juta per Bulan
# Scraping: Ijazah Fisik Jokowi Tak Pernah Ditunjukkan, Pengamat: Memperkuat Dugaan Teori Konspirasi Politik
# Scraping: Protes Warga Pati hingga Usul Pemakzulan Bupati Sudewo, Kedekatan Prabowo-Mega Disebut Jadi Penentu
# Scraping: Fero Walandouw Vakum dari Dunia Hiburan, Fokus di Politik dan Bisnis Sejak Jadi Komisaris Perusahaan
# Scraping: Messi dan Masalah Politik yang Memungkinkan Tinggalkan Barcelona pada 2018
# Scraping: Pakar Hukum Nilai Pemberian Amnesti ke Hasto Bagian dari Politik Prabowo
# Scraping: Rocky Gerung Sebut Kasus Hasto Bentuk Dendam Politik Jokowi, tapi Diselamatkan Prabowo Lewat Amnesti
# Scraping: Politik Kebangsaan: Kembali ke Rumah Rakyat, Menjaga Arah Sejarah
# Scraping: DPR Bantah Pemberian Amnesti kepada Hasto Mengandung Unsur Politik: Dari Awal Kasus Hasto Janggal
# Scraping: Kader PDIP Yasonna Laoly Sebut Amnesti Hasto Kristiyanto Inisiatif Presiden, Bukan Transaksi Politik
# Scraping: Abolisi untuk Tom Lembong dan Amnesti buat Hasto Dinilai Bisa Redakan Ketegangan Politik
# Scraping: Jokowi Sebut Ada Tokoh Besar di Balik Isu Pemakzulan Gibran dan Tudingan Ijazah Palsu
# Scraping: Momen Makan Bakmi Jawa Bareng di Solo dan Kasus Tom Lembong-Hasto Kristiyanto
# Scraping: MK Tolak Syarat Capres Harus Sarjana, HNW: Ijazah Tak Diatur UUD
# Scraping: Jawab Tudingan Tom Lembong Soal Kasus Impor Gula, Kejagung: Murni Kepentingan Hukum Bukan Politik
# Scraping: Tokoh Cipayung Plus Gabung Golkar Lewat AMPI, Jefri Gultom: Politik Itu Etika Melayani
# Scraping page: 3
# Scraping: Membedah Sakit Jokowi Versi Rocky Gerung:  Bukan Alergi Kulit Tapi Gangguan Kejiwaan
# Scraping: Respons Usul Sahroni ke Jokowi, Rampai Nusantara: SBY saat Ini Jabat Ketua Majelis Tinggi Demokrat
# Scraping: Sahroni Sarankan Jokowi Perlu Contoh SBY Usai Lengser, Serahkan Urusan Politik ke Anak
# Scraping: Bambang Irawan: Tudingan Haji Isam Bakal Ambil Alih PPP Isu yang Menyudutkan
# Scraping: Hetifah Tegaskan Komitmen Perempuan dalam Politik Nasional: Bukan Hanya Pelengkap, Tetapi Penentu
# Scraping: KPK Lakukan Kajian Potensi Korupsi pada Pembiayaan Politik
# Scraping: Megawati-Prabowo, Secangkir Teh dan Harapan Masa Depan Indonesia
# Scraping: Kembali ke Musik, Sule Rilis Lagu Bertemakan Isu Sosial dan Politik
# Scraping: Prilly Latuconsina Bantah Terlibat Mendukung Pasangan Calon di Pilpres 2024
# Scraping: Pernyataan Politisi PDIP Deddy Sitorus soal Utusan yang Mencatut Nama Jokowi Cenderung Cari Sensasi
# Scraping: Hasto Kristiyanto Teriak Merdeka, Klaim Perkaranya Sangat Kental Muatan Politik
# Scraping: Bukan Isu Politik, Analis Ingatkan Fokus pada Substansi Kasus Korupsi Pertamina: Ungkap Dalangnya!
# Scraping: Perspektif Baru Memahami Konstruksi Sejarah, Asas, Ciri, dan Doktrin Partai Golkar
# Scraping: Hari Perempuan Internasional, Ade Fitrie Kirana: Momen Membangun Hak-hak Perempuan di Bidang Politik
# Scraping: Luncurkan PCB, Wakil Ketua Umum Golkar: Bicara Politik Bukan Hanya di 'Ruang Gelap' Saja
# Scraping: Mesut Ozil Terjun ke Dunia Politik, Bergabung Partai Berkuasa Turki Jadi Pembuat Keputusan Senior
# Scraping: Putusan MK Gelar PSU di 24 Daerah Harus Jadi Bahan Evaluasi DPR Perbaiki Sistem Politik dan Pemilu
# Scraping: Lestari Moerdijat: Program Remaja Bernegara Langkah NasDem Memperkenalkan Politik ke Generasi Muda
# Scraping: Eddy Soeparno: Keterlibatan Perempuan di Politik Syarat Utama Demokrasi Berkualitas
# Scraping: VIDEO Gus Yahya Tegaskan NU Tidak Boleh Didorong Jadi Identitas Politik
# Scraping page: 4
# Scraping: Haji Faisal Bicara Kemungkinan Fuji Terjun ke Dunia Politik, Nilai sang Anak Sudah Ada Niat
# Scraping: Haji Faisal Dukung Fuji Terjun ke Politik, Buntut Buat Konten Bareng Verrell Bramasta di Gedung DPR
# Scraping: Anak Uya Kuya Tak Tertarik Geluti Politik di Indonesia, Pilih Fokus Berkarier di Amerika
# Scraping: Wejangan Saldi Isra di Sidang Sengketa Pilkada: Persaudaraan Jangan Rusak Karena Politik
# Scraping: Verrell Bramasta Ajak Fuji Keliling DPR RI Tuai Pujian, Kenalkan Dunia Politik ke Anak Muda
# Scraping: Pertemuan Prabowo dengan Megawati, PDIP Sebut Bila Terjadi Tak Akan Ada Deal Politik
# Scraping: Isi Obrolan Jokowi dan Sri Sultan di Jogja, Ngaku Cuma Silaturahmi usai Lengser Presiden
# Scraping: INFOGRAFIS Mengapa Jokowi Terus Mendapat Hujatan Politik?
# Scraping: 4 Hal yang Membuat Jokowi Terus 'Diserang' oleh PDIP, Analisis Pakar Politik
# Scraping: Kanker Usus Nurul Qomar Kambuh Sejak Sibuk Kampanye Politik
# Scraping: Alasan Fedi Nuril Berani Bersuara Keras soal Politik, Singgung Kemarahan
# Scraping: Kecelakaan Pesawat Jeju Air Membuat Drama Politik di Korea Selatan Mereda dan Pemakzulan Presiden
# Scraping: Refly Harun & Rocky Gerung Seret Nama Jokowi dalam Kasus Hasto, Tuding Lakukan Balas Dendam Politik
# Scraping: Karier Politik Jokowi Pasca-Dipecat PDIP Dinilai Lebih Cocok ke Gerindra
# Scraping: Tegaskan Golkar Terbuka untuk Siapa Pun, Bahlil Sebut Keputusan Ada di Jokowi
# Scraping: 11 Deretan Artis yang Terjun di Pilkada 2024, ada Rano Karno, Kris Dayanti hingga Ramzi
# Scraping: Politisi Senior Thailand Diduga Perintahkan Ajudan Tembak Mati Anak Angkatnya
# Scraping: Sikapi Kekalahan di Pilkada 2024, RK: Jakarta Akan Selalu Menjadi Episentrum Politik Indonesia
# Scraping: Jaga Stabilitas Politik, Gugatan Hasil Pilkada ke MK Harus Disikapi dengan Arif dan Bijaksana
# Scraping: Krisis Politik Sedang Melanda Korea Selatan
# Scraping page: 5
# Scraping: Prancis Menghadapi Krisis Politik yang Parah, Suara-suara Menyerukan Macron Tinggalkan Istana Elysee
# Scraping: Ayu Ting Ting Enggan Terjun ke Politik, Sadar Tak Punya Kemampuan
# Scraping: Pemilihan Kepala Daerah 2024, Aktivis: Jaga Pilkada Sebagai Anak Kandung Reformasi
# Scraping: Pengamat Soroti Praktik Dinasti Politik, Dianggap dapat Mencederai Prinsip Demokrasi
# Scraping: Menteri Agama Ungkap 500 Kasus Perceraian Terjadi Akibat Perbedaan Pilihan Politik
# Scraping: Klarifikasi di DPR, Jaksa Agung: Kasus Tom Lembong Tak Ada soal Politik
# Scraping: Pesan Ibas Yudhoyono ke Generasi Muda untuk Terlibat Aktif dalam Politik
# Scraping: Novel Baswedan: Kebijakan Politik dan Penegakan Hukum, 2 Sektor yang Harus Dibereskan
# Scraping: Raffi Ahmad Ungkap Kejadian Mistis di Rumah, Sebut Jeje Tiba-tiba Tak Bisa Jalan: Persaingan Politik
# Scraping: Baleg DPR Usulkan Revisi 8 UU Soal Politik Gunakan Metode Omnibus Law
# Scraping: Eduardo Camavinga Dukung Vinicius Junior, Sindir Ballon d'Or Hanya Sebatas Politik Sepak Bola
# Scraping: Prabowo Diharapkan Bisa Distribusikan Kekuasaan Politik Secara Adil
# Scraping: Bawaslu Khawatirkan Rendahnya Pengetahuan Politik Anak Muda Jelang Pilkada 2024
# Scraping: Bertransformasi dari Musisi Menjadi Politisi, Giring Ganesha Ingin Ikuti Jejak Ahmad Dhani
# Scraping: Melayat Benny Laos, Rocky Gerung: Selamat Jalan Ben, Gue Tetap Bersahabat dengan Keluarga Lu
# Scraping: Ketika Ekonomi Lesu, Apakah Politik yang Bergairah Bisa Menjadi Solusi?
# Scraping: Jadi Wakil Ketua MPR, Rusdi Kirana: Berpolitik bagi Saya Pengabdian
# Scraping: Kritik Sindiran Zelenskyy ke JD Vance, Partai Republik: Jangan Ikut Campur Urusan Politik AS
# Scraping: Rekam Jejak Marissa Haque di Dunia Politik: Mengawali Karier Bersama PDI Perjuangan di DPR RI
# Scraping: Menteri Investasi: Kolaborasi Kunci Hadapi Ancaman Global
# Scraping page: 6
# Scraping: Pengamat Sebut Munaslub Tidak Produktif, Kadin Diminta Fokus pada Pertumbuhan Ekonomi Indonesia
# Scraping: Dinar Candy Mengaku Tolak Tawaran Tiga Partai Besar, Belum Tertarik Jajal Dunia Politik
# Scraping: Reaksi Raffi Ahmad Dicap jadi Makelar Jabatan: Apa Urusannya Sama Gua?
# Scraping: Tak Mau Ikut Arus Berpolitik, Sule Tetap Dukung Teman Sesama Seniman yang Ikut Pilkada
# Scraping: Sule Menolak saat Ditawari Banyak Parpol, Ogah Popularitasnya Dimanfaatkan
# Scraping: Ogah Terjun ke Politik karena Tak Punya Kapasitas, Sule: Saya Tahu Apa? Masak Saya Planga-plongo
# Scraping: 2 Modal Politik Anies jika Bentuk Partai Baru, Pengamat Singgung Basis Massa
# Scraping: Anies Baswedan Gagal Maju di Pilkada 2024, NasDem: Kartunya Enggak Pernah Mati
# Scraping: Tanggapan Ale The Adams Soal Larangan Musisi Singgung Isu Politik di Panggung Konser
# Scraping: Pengamat Nilai Presiden Terpilih Prabowo Subianto Bakal Terbebani Warisan Politik Jokowi
# Scraping: Luna Maya Ikut Resah Lihat Kondisi Politik Indonesia, Minta Media Kawal Keputusan MK
# Scraping: Usai Hengkang dari Golkar, Wanda Hamidah Akui Tidak Mau Terjun Politik Dulu
# Scraping: Kiky Saputri Menangis Khawatirkan Nasib Marshel Widianto di Politik: Jangan Kecewain Banyak Orang
# Scraping: Pakar Komunikasi Politik Benny Susetyo: Bahaya Bayang Kartel Politik Pilkada 2024
# Scraping: PDIP Ditinggal Sendirian, Mahfud MD: Permainan Politik di Lapangan Memang Macam-macam
# Scraping: BUMN Diminta Jaga Profesionalisme dan Bisa Jadi Tempat Bekerja Kondusif
# Scraping: Jelang Pilkada 2024, Himpunan Putra Putri Keluarga Angkatan Darat Ajak Jaga Suasana Damai & Kondusif
# Scraping: 4 Skenario Politik Pilkada Jakarta 2024: Anies Baswedan Lawan Kotak Kosong hingga Muncul Nama Baru?
# Scraping: Revisi Undang-undang Dewan Pertimbangan Presiden untuk Siapa?
# Scraping: Sepak Terjang Hamzah Haz di Dunia Politik, Puncak Karier Jadi Wapres Dampingi Megawati
# Scraping page: 7
# Scraping: Wejangan Surya Paloh ke Kaesang: Jangan Pensiun dari Politik, Minimal 5 Sampai 6 Pemilu ke Depan
# Scraping: Diisi Banyak Politisi, Ray Rangkuti Nilai Pemilihan Anggota BPK Rawan Konflik Kepentingan
# Scraping: Bertemu Ketum Partai Demokrat, Ketua MPR RI Bamsoet Diskusikan Sistem Politik dan Kondisi Demokrasi
# Scraping: Jelang Pilkada Kemenag Siapkan Antisipasi Munculnya Konflik Sentimen Agama
# Scraping: Pembentukan Pansus Angket Haji Harus Berdasarkan Urgensi, Jangan Hanya Kepentingan Politik Sesaat
# Scraping: Dituding Pengangguran, Azriel Hermansyah Beberkan Usaha Miliknya, Sebut Berencana Masuk Politik
# Scraping: Masih Ingin Tenang, Raffi Ahmad Belum Putuskan Terjun ke Politik
# Scraping: Mayoritas Warga Israel Lebih Memilih Netanyahu Pensiun dari Politik, Hasil Jajak Pendapat
# Scraping: Wawancara Eksklusif - Ilham Habibie Siap Ikut Kontestasi Pilkada 2024, Pesan Kuping Harus Tebal
# Scraping: Keynote Speech Academia Politica IMM, HNW: Generasi Muda Harus Punya Kesadaran Pentingnya Berpolitik
# Scraping: Usung Marshel jadi Calon Wakil Wali Kota Tangsel, Gerindra: Pasti Bisa Memajukan Pemuda
# Scraping: Azriel Hermansyah Sempat Ditawari Nyaleg, Tapi Menolak karena Belum Siap
# Scraping: Pengamat Politik: Dinamika Politik Masa Depan Makin Berat UU MD3 Sebaiknya Direvisi
# Scraping: Bahlil Klaim Pemberian Izin Usaha Tambang ke Ormas Tidak Ada Kaitan dengan Politik
# Scraping: KPK Tepis Isu Pencarian Harun Masiku Cuma Gimik Politik
# Scraping: Qodari Ungkap Dua Opsi Jokowi Setelah Tak Lagi Jadi Presiden: tapi Saya Cenderung yang Pertama
# Scraping: Jokowi Izinkan Ormas Keagamaan Kelola IUP Tambang, Anggota DPR: Jadi Komoditas Transaksi Politik
# Scraping: Jokowi Diprediksi Tetap Aktif di Politik Meski Tak Lagi Jadi Presiden, Siapkan Perangkat Antipensiun
# Scraping: Hasto PDIP Singung Sisi Gelap Demokrasi dan Bicara Politik Harus Belajar dari Olahraga
# Scraping: DPR Yakin Pemerintah Bisa Jaga Stabilitas Politik Agar Tidak Ganggu Sektor Ekonomi
# Scraping page: 8
# Scraping: Kementerian Agama Siapkan Naskah Khotbah Jumat hingga Desember 2024, Tidak Ada Tema Soal Politik
# Scraping: Anies Baswedan Bicara soal Toxic dan Pakem Politik
# Scraping: Kunjungan ke London, Airlangga Ungkap Sukses Indonesia Jaga Ekonomi Tumbuh hingga Stabilitas Politik
# Scraping: Universitas Columbia Hadapi Tekanan Politik, Mahasiswa yang Protes Genosida Israel Kemah di Kampus
# Scraping: Laron-laron Politik Berburu Kuasa
# Scraping: Global Parliamentary Forum 2024, Komisi VII DPR Tunjukkan Komitmen Indonesia Soal Kesetaraan Gender
# Scraping: Dimas Oky: Usai Putusan MK, Indonesia Menuju Keseimbangan dan Equilibrium Politik Baru
# Scraping: Cak Imin: Putusan Mahkamah Konstitusi adalah Masa Depan Politik Indonesia
# Scraping: Bertemu SBY di Cikeas, Prabowo Tak Singgung Adanya Pembahasan Politik
# Scraping: Pertemuan Prabowo dan Megawati Dinilai sebagai Upaya Redam Ketegangan Politik
# Scraping: Budi Arie: Jangan Diadu Domba Antara Prabowo dan Jokowi
# Scraping: Menteri Bahlil Usai Salat Idulfitri: Politik Sudah Selesai, Hari Ini Saling Memaafkan
# Scraping: Catatan Ketua MPR RI: Menghayati Berkah Idul Fitri Bagi Harmonisasi Kehidupan Bersama
# Scraping: Balik Bermusik Usai Gagal di Politik, Giring Ganesha Akui Kesulitan
# Scraping: Habis Miliaran Tapi Gagal, Giring Ganesha Pikir-pikir Maju Kontestasi Pileg 2029, Kapok?
# Scraping: Utamakan Persaudaraan Kubu Prabowo Tawarkan Rekonsiliasi Usai Pilpres 2024
# Scraping: Suasana Politik di Bulan Puasa, HNW Sebut Agama adalah Katalisator Bagi Pemeluknya untuk Bangkit
# Scraping: Dinasti Politik Yasin di Kabupaten Bogor Ambruk di Pemilu 2024, Tak Lolos DPR RI dan DPRD
# Scraping: Terinspirasi Verrell Bramasta Lolos ke Senayan, Athalla Naufal Berencana Terjun ke Politik
# Scraping: Kiai Said Aqil Siroj Ingatkan Bahayanya Jika Agama Menjadi Alat Politik
# Scraping page: 9
# Scraping: Sekjen NasDem Kutip Pernyataan Azyumardi Azra: Kalau Jokowi Bilang Mau Pulang ke Solo Itu 'Sinyal'
# Scraping: RUU DKJ Gubernur Dipilih Presiden, Pengamat Ingatkan Pentingnya Partisipasi Politik Publik Jakarta
# Scraping: Pelaksanaan Pilkada Tetap November 2024, PKB : Cegah Spekulasi Politik
# Scraping: Ketua Muhammadiyah Jateng Sebut Pemilu Memiliki Prosedur dan Aturan yang Harus Diikuti
# Scraping: Jokowi Sebut Kondisi Politik Indonesia Kini Masih Stabil
# Scraping: Jokowi Akui Bertemu Surya Paloh Bahas Politik
# Scraping: Menpora Dito Nilai Mantan Atlet yang Terjun ke Politik Baik Untuk Susun Kebijakan yang Tepat Sasaran
# Scraping: Ketua Tim Pembela Prabowo-Gibran Bantah Berita Korupsi, Yusril: Ini Adalah Pembusukan Politik
# Scraping: Franz Magnis Suseno Sayangkan Pelanggaran Etik Komisioner KPU
# Scraping: PA 212 Larang Jemaah Bawa Atribut Politik Saat Acara Istighosah Kubro Malam Nanti di Kemayoran
# Scraping: Fakta Pria di Sumsel Aniya Kedua Orang Tua, Sempat Nonton Debat Capres, Tersinggung Ucapan Korban
# Scraping: Sivitas Akademika Kritik Presiden Jokowi, Cak Imin Singgung Sinyal Merah dan Vonis Rakyat
# Scraping: Airlangga Puji Penampilan Prabowo dalam Debat Terakhir: Rendah Hati Sehingga Turunkan Tensi Politik
# Scraping: Sedang Jalani Kegiatan Politik, Alasan Bella Shofie Tak Hadir dalam Pemakaman Ibu Diungkap sang Ayah
# Scraping: Anies Baswedan : Sah-sah Saja Akademisi Bicarakan Soal Kondisi Politik Indonesia
# Scraping: Putra Anies Baswedan dan Putri Cak Imin Ngaku Belum Ingin Terjun ke Politik, Kenapa?
# Scraping: FSGI Minta Guru Tak Promosikan Pilihan Politiknya pada Pemilu 2024 di Ruang Kelas
# Scraping: Sukses di Dunia Akting, Reza Rahadian Ngaku Ingin Jadi Menteri jika Terjun ke Politik
# Scraping: Pengamat Politik Unas Pertanyakan Integritas Politik Presiden yang Memihak dan Berkampanye
# Scraping: Akui Ada Beban Jadi Pertimbangan Reza Artamevia Mundur dari Politik
# Scraping page: 10
# Scraping: Reza Artamevia Umumkan Batal Maju Jadi Caleg, Ingin Netral dan Fokus Bermusik
# Scraping: Soal Pernyataan Presiden Boleh Memihak, Pengamat: Kian Menguatkan Arah Politik Jokowi
# Scraping: Curhat The Virgin Ikut Kena Dampak Ketika Ahmad Dhani Mulai Masuk Politik
# Scraping: Dari Aktor Terjun ke Politik, Stefan William Akui Tak Ubah Penampilan Meski Fokus Nyaleg: Apa Adanya
# Scraping: Akun Instagram Sempat Diretas, Mahfud MD Menolak Ada Pengusutan
# Scraping: Semua Pihak Diminta Jaga Kondusivitas untuk Wujudkan Pemilu yang Damai
# Scraping: Pengamat Sayangkan Alasan Maruarar Hengkang dari PDIP, seperti Nyatakan Sikap Berhadap-hadapan
# Scraping: Ketua Partai Restorasi Jepang Kembali Serukan Penghapusan Partai Komunis Jepang dari Sistem Politik
# Scraping: Kiesha Alvaro Masukkan Politik Dalam Daftar Kesibukan di 2024
# Scraping: Polisi Pastikan Pengancam Anies Baswedan di Kaltim Bukan karena Politik Tapi Spontan
# Scraping: Dapat Tawaran Terjun ke Politik, Ariel NOAH Menolak
# Scraping: Sambut Pergantian Tahun, Ketua MPR RI Bamsoet Berharap Pemilu 2024 Lahirkan Pemimpin Semahir Jokowi
# Scraping: Kaleidoskop Politik 2023: Prabowo Subianto Hattrick Jadi Capres
# Scraping: Wapres Maruf Amin Buka Suara Soal 2 Putrinya yang Beda Pilihan Politik di Pilpres 2024, Apa Katanya?
# Scraping: Meski Sukses jadi Musisi, Jeje Govinda Tak Mau Lewatkan Kesempatan Terjun ke Politik, Akui Serius
# Scraping: Zulhas Ingatkan Masyarakat Tetap Jaga Persaudaraan Meski Berbeda Pilihan Politik di Pilpres
# Scraping: Ramai Soal Pernyataan Ketua Umum Parpol Terkait Gerakan Tahiyat, Ini Komentar Rektor UMJ
# Error article: HTTPSConnectionPool(host='www.tribunnews.com', port=443): Read timed out. (read timeout=10)
# Scraping: Singgung Tak Mau Joget-joget, Ganjar Pranowo: Purifikasi Politik untuk Edukasi
# Scraping: Punya Peran Penting dalam Bisnis dan Politik, Berikut Manfaat AI yang Perlu Kamu Tahu
# Scraping: Sebelum Ganjar Pranowo Pensiun, Alam Ganjar Tak Berniat Masuk Politik demi Hindari Gesekan
# Total articles scraped: 199
# Berhasil disimpan ke tribunnews_politik_full.csv
#                                                title  \
# 0  Tebar Pesona di Tengah Banjir, Masih Efektifka...
# 1  PSI Puji Prabowo Akui Keberhasilan Jokowi: Pad...
# 2  Nahdlatul Ulama Diharapkan Tetap Menjadi Rumah...
# 3  Said Abdullah Sebut Regenerasi Pemilih Muda Ja...
# 4  Ketua PSI Jabar: Bakal Ada Badai Politik Usai ...
#
#                                                  url  \
# 0  https://www.tribunnews.com/nasional/7763757/te...
# 1  https://www.tribunnews.com/nasional/7760973/ps...
# 2  https://www.tribunnews.com/nasional/7759053/na...
# 3  https://www.tribunnews.com/nasional/7758786/sa...
# 4  https://www.tribunnews.com/nasional/7755070/ke...
#
#                                              content
# 0  TRIBUNNEWS.COM, JAKARTA - Istilah tebar pesona...
# 1  TRIBUNNEWS.COM, AMBON - Ketua Harian Partai So...
# 2  TRIBUNNEWS.COM, JAKARTA - Nahdlatul Ulama (NU)...
# 3  TRIBUNNEWS.COM, SURABAYA - Ketua DPD PDI Perju...
# 4  TRIBUNNEWS.COM, BANDUNG - Ketua DPW PSI Jawa B...

# %%
print("Total articles scraped:", len(data))
# Out:
# Total articles scraped: 199

# %%
# df = pd.DataFrame(data)
# df.to_csv(
#     "tribunnews_politik_full2.csv",
#     index=False,
#     encoding="utf-8-sig"
# )

# print("Berhasil disimpan ke tribunnews_politik_full2.csv")
# print(df.head())

# %%
# title_tag = articles[0].select_one("h3 a")
# print(title_tag)

# test_url = title_tag["href"]
# print(test_url)
# print(get_article_content(test_url)[:500])

# %%
# for i, art in enumerate(articles, start=1):
#     try:
#         # title_tag = art.select_one("h3 a")
#         if not title_tag:
#             continue

#         title = title_tag.get_text(strip=True)
#         link = title_tag["href"]

#         date_tag = art.select_one(".article__date")
#         date = date_tag.get_text(strip=True) if date_tag else None

#         print(f"[{i}] Scraping:", title)

#         content = get_article_content(link)
#         if content is None:
#             print("Konten kosong, skip")
#             continue

#         data.append({
#             "source": "tribunnews",
#             "title": title,
#             "date": date,
#             "url": link,
#             "content": content,
#             "scraped_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#         })

#         time.sleep(2)

#     except Exception as e:
#         print("Skip article:", e)


# df = pd.DataFrame(data)
# df.to_csv(
#     "tribunnews_politik_full.csv",
#     index=False,
#     encoding="utf-8-sig"
# )

# print("Berhasil disimpan ke tribunnews_politik_full.csv")
# print(df.head())
